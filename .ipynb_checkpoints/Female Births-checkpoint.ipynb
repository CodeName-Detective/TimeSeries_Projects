# 1959-12-15      47
# ...

# %%
split = int(len(X)/2)
X1,X2 = X[:split],X[split:]
mean1,mean2 = X1.mean(),X2.mean()
var1,var2 = X1.var(),X2.var()
print('mean1=%f, mean2=%f' %(mean1,mean2))
print('var1=%f, var2=%f' %(var1,var2))
# Out:
# mean1=39.763736, mean2=44.153846
# var1=49.485308, var2=49.059074

# %% [markdown]
# ### Graphs

# %%
plt.figure(figsize=(20,5))
plt.plot(df['Date'],df['Births'])

# %% [markdown]
# # Hypothesis Testing - Augmented Dickey Fuller Test

# %% [markdown]
# - Null Hypothesis = The time series is non-stationery

# %%
from statsmodels.tsa.stattools import adfuller
test_result = adfuller(df['Births'])

# %%
test_result
# Out:
# (-4.831115135904671,
#  4.740241052762431e-05,
#  6,
#  357,
#  {'1%': -3.44880082033912,
#   '5%': -2.869670179576637,
#   '10%': -2.5711012838861036},
#  2337.3931318368122)

# %%
print('p value of the test is %f' % test_result[1])
# Out:
# p value of the test is 0.000047

# %% [markdown]
# - Reject Null Hypothesis

# %% [markdown]
# # Decompsoing Timeseries

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
X1 = df.set_index('Date')
decompse_result=seasonal_decompose(X1['Births'],model='multiplicative')
decompse_result.plot()
plt.figure(figsize=(20,5))
plt.show()

# %% [markdown]
# # ACF(Auto Correlation Function) and PACF(Partial Auto Correlation Function)- Plot

# %%
from statsmodels.tsa.stattools import acf,pacf
lag_acf = acf(df['Births'],nlags=20)
lag_pacf = pacf(df['Births'],nlags=20,method='ols')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(20,10))
#Plot ACF:
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(df['Births'])),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(df['Births'])),linestyle='--',color='gray')
plt.title('Auto Correlation Function')


#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(df['Births'])),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(df['Births'])),linestyle='--',color='gray')
plt.title('partial Auto Correlation Function')

plt.tight_layout()

# %% [markdown]
# # ARIMA Model

# %%
from statsmodels.tsa.arima_model import ARIMA
train,test = X[:360],X[350:]
train['Births'].dropna(inplace=True)
test['Births'].dropna(inplace=True)
arima_model = ARIMA(train['Births'],order=(2,0,2))
results_arima = arima_model.fit(disp=-1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   % freq, ValueWarning)

# %%
len(results_arima.forecast(steps=14)[0]),len(test['Births'])
# Out:
# (14, 14)

# %%
result_data = {'predict':results_arima.forecast(steps=14)[0],'Actual':test['Births']}
predicted_df = pd.DataFrame(result_data)
predicted_df
# Out:
#               predict  Actual
# Date
# 1959-12-17  41.655153      39
# 1959-12-18  41.949721      40
# 1959-12-19  41.656392      42
# 1959-12-20  41.929338      42
# 1959-12-21  41.657214      53
# 1959-12-22  41.910119      39
# 1959-12-23  41.657662      40
# 1959-12-24  41.891991      38
# 1959-12-25  41.657775      44
# 1959-12-26  41.874888      34
# 1959-12-27  41.657589      37
# 1959-12-28  41.858746      52
# 1959-12-29  41.657138      48
# 1959-12-30  41.843507      55

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(predicted_df['Actual'],predicted_df['predict'])
mse
# Out:
# 40.811468189586286

# %%
np.sqrt(mse)
# Out:
# 6.388385413356515
